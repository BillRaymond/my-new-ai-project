# %% [markdown]
# ## This model model will accept X and Y coordinates
# When we submit a new X value, the model will predict the probably of the Y value

# %%
print("Hello World")
# Out:
# Hello World

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ### 🛠️ Model preparedness
# 1. Create a model
# 2. Define the training dataset
# 3. Create the model

# %%
# Create the model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# Define X and Y
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# Define a model 
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 119ms/step - loss: 42.4007
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 33.3616
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 26.2500
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 20.6549
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 16.2529
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 12.7896
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0647
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9209
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2342
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9071
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8630
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0415
# ...

# %% [markdown]
# ## 🚀 Model prediction

# %%
# Predict what the value of Y will be
# is the next X value is 10
prediction = model.predict([10.0])
print("Prediction: ", prediction)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Prediction:  [[31.001976]]
